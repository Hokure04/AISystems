# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt

# %%
df = pd.read_csv('diabetes.csv')
df.fillna(0, inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
mean_values = {}
variance_values = {}
std_values = {}
quantile_25 = {}
quantile_50 = {}
quantile_75 = {}
min_values = {}
max_values = {}
count_values = {}
for column in df.columns:
    data = df[column]
    mean = sum(data)/len(data)
    mean_values[column] = mean
    variance = sum((x - mean)**2 for x in data)/(len(data)-1)
    variance_values[column] = variance
    count_values[column] = data.count()
    std_values[column] = sqrt(variance)
    quantile_25[column] = np.percentile(data, 25)
    quantile_50[column] = np.percentile(data, 50)
    quantile_75[column] = np.percentile(data, 75)
    min_values[column] = min(data)
    max_values[column] = max(data)
stats_df = pd.DataFrame({
    'count': count_values,
    'mean': mean_values,
    'variance': variance_values,
    'std_dev': std_values,
    'min': min_values,
    'quantile_25': quantile_25,
    'quantile_50': quantile_50,
    'quantile_75': quantile_75,
    'max': max_values
})
stats_df = stats_df.T
stats_df
# Out:
#              Pregnancies      Glucose  BloodPressure  SkinThickness  \
# count         768.000000   768.000000     768.000000     768.000000
# mean            3.845052   120.894531      69.105469      20.536458
# variance       11.354056  1022.248314     374.647271     254.473245
# std_dev         3.369578    31.972618      19.355807      15.952218
# min             0.000000     0.000000       0.000000       0.000000
# quantile_25     1.000000    99.000000      62.000000       0.000000
# quantile_50     3.000000   117.000000      72.000000      23.000000
# quantile_75     6.000000   140.250000      80.000000      32.000000
# max            17.000000   199.000000     122.000000      99.000000
#
#                   Insulin         BMI  DiabetesPedigreeFunction         Age  \
# count          768.000000  768.000000                768.000000  768.000000
# mean            79.799479   31.992578                  0.471876   33.240885
# variance     13281.180078   62.159984                  0.109779  138.303046
# std_dev        115.244002    7.884160                  0.331329   11.760232
# min              0.000000    0.000000                  0.078000   21.000000
# quantile_25      0.000000   27.300000                  0.243750   24.000000
# quantile_50     30.500000   32.000000                  0.372500   29.000000
# quantile_75    127.250000   36.600000                  0.626250   41.000000
# max            846.000000   67.100000                  2.420000   81.000000
#
#                 Outcome
# count        768.000000
# mean           0.348958
# variance       0.227483
# std_dev        0.476951
# min            0.000000
# quantile_25    0.000000
# quantile_50    0.000000
# quantile_75    1.000000
# max            1.000000

# %%
df.hist(bins=20, figsize=(15,10), grid=False, color='skyblue', edgecolor='black')
plt.suptitle('Гистограммы признаков', fontsize=16)
plt.tight_layout()
plt.show()
